# %% [markdown]
# # Session 2: Python Basics
#
# ## Objective
# Learn the fundamentals of Python programming, including variables, data types, operators, conditionals, and loops.

# %% [markdown]
# ## 1. Variables, Data Types, and Operators

# %%
# Variables
name = "Addis"  # String
age = 25         # Integer
height = 5.2     # Float
is_student = True  # Boolean

print(name, age, height, is_student)

# %%
# Operators Example
x = 10
y = 3

print("Addition:", x + y)
print("Exponentiation:", x ** y)
print("Logical Operation:", x > y and y < 5)

# %% [markdown]
# ## 2. Conditional Statements (if/else)

# %%
age = 18
if age >= 18:
    print("You are an adult.")
elif age >= 13:
    print("You are a teenager.")
else:
    print("You are a child.")

# %% [markdown]
# ## 3. Loops (for, while)

# %%
# For Loop
for i in range(5):
    print("Iteration:", i)

# %%
# While Loop
count = 0
while count < 5:
    print("Count is:", count)
    count += 1

# %% [markdown]
# ## Activity: Basic Calculations

# %%
a = float(await input("Enter first number: "))

# %%
b = float(await input("Enter second number: "))

# %%
print("Sum:", a + b)
print("Difference:", a - b)
print("Product:", a * b)
print("Quotient:", a / b)

# %% [markdown]
# ## Activity: Print First 10 Even Numbers

# %%
for i in range(2, 21, 2):
    print(i)
